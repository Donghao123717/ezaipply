# %%
import csv
from collections import OrderedDict

rows1 = [
    ["David", "Applied Mathematics", "Harvard University"],
    ["Tioluwalase (Lase) Adelakun", "Psychology", "Harvard University"],
    ["NanaYaa", "Sociology (Data Analytics track); African Studies (secondary)", "Harvard University"],
    ["Opeoluwa \"Ope\" Falako", "Molecular and Cellular Biology; African American Studies (secondary)", "Harvard University"],
    ["Chidera Ejikeme", "History of Science", "Harvard University"],
    ["Daniela Diaz", "Economics", "Harvard University"],
    ["Rebecca Thompson", "Sociology", "Harvard University"],
    ["Wonuola Obasa", "Environmental Science and Public Policy", "Harvard University"],
    ["Jaeschel Acheampong", "Biomedical Engineering", "Harvard University"],
    ["Ryyan Pritchett", "Sociology", "Harvard University"],
    ["Lara Dada", "Economics", "Harvard University"],
    ["Aaron Shirley", "History of Science; Sociology", "Harvard University"],
    ["Gene Nartey", "Computer Science; Art, Film, and Visual Studies (secondary)", "Harvard University"],
    ["Halima Badri", "Psychology", "Harvard University"],
    ["Aissata Bah", "Studies of Women, Gender, and Sexuality; History and Literature", "Harvard University"],
    ["Daylan Davis", "Government; Theatre, Dance, and Media (secondary)", "Harvard University"],
    ["Marissa Joseph", "History and Literature", "Harvard University"],
    ["Unique Hodge", "Integrative Biology", "Harvard University"],
    ["Demya Toogood", "Economics", "Harvard University"],
    ["Walter Ohams", "Applied Mathematics", "Harvard University"],
    ["RuQuan Brown", "Linguistics", "Harvard University"],
    ["Char Deslandes", "History and Literature; Ethnicity, Migration, Rights (secondary)", "Harvard University"],
    ["Chibuike Ukakwe", "Biomedical Engineering", "Harvard University"],
    ["Kaelin Ray", "Neuroscience", "Harvard University"],
    ["Kareem King", "History of Science", "Harvard University"],
    ["Artha Jonassaint", "Government; Global Health and Health Policy", "Harvard University"],
    ["Mayi Hughes", "Sociology", "Harvard University"],
    ["Rich Jenkins", "Sociology", "Harvard University"],
    ["Tijesunimi Borode", "Neuroscience", "Harvard University"],
    ["Kiersten Hash", "Government", "Harvard University"],
    ["Kidist Alemu", "Computer Science", "Harvard University"],
    ["Andrea Agola", "Sociology; International Studies (minor)", "Dartmouth College"],
    ["Nuna Agbodza", "Biological Sciences", "Dartmouth College"],
    ["Adrian Chimboza", "Economics (modified)", "Dartmouth College"],
    ["Chidera Duru", "Economics; African and African American Studies", "Dartmouth College"],
    ["Chinazom Onubogu", "Engineering", "Dartmouth College"],
    ["Triumph Kia T", "Mathematics", "Dartmouth College"],
    ["Joy M", "Computer Science", "Dartmouth College"],
    ["Emmanuel D", "Computer Science; Human-Centered Design", "Dartmouth College"],
    ["Grace B", "Economics", "Dartmouth College"],
    ["Yujin Angolio", "Mechanical and Aerospace Engineering", "Princeton University"],
    ["Tomi Johnson", "Woodrow Wilson School", "Princeton University"],
    ["Ava Adelaja", "Comparative Literature", "Princeton University"],
    ["Wunnyuriti Ziblim", "Civil and Environmental Engineering", "Princeton University"],
    ["Liliane Kevine Ikirezi", "Electrical Engineering", "University of Pennsylvania"],
    ["Sandra Urusaro", "Nursing", "University of Pennsylvania"],
    ["Sonari Chidi", "Cinema; Africana Studies", "University of Pennsylvania"],
    ["Chiemela Ohanele", "Natural Sciences (biology-focused profile)", "University of Pennsylvania"],
    ["Anea Moore", "Sociology; Urban Studies", "University of Pennsylvania"],
    ["Richard Oti", "6-14 Computer Science, Economics, and Data Science; 15-2 Business Analytics", "Massachusetts Institute of Technology"],
    ["Veronica M.", "6-2 Electrical Engineering and Computer Science", "Massachusetts Institute of Technology"],
    ["Vincent A.", "6-3 Computer Science and Engineering", "Massachusetts Institute of Technology"],
    ["Selam G.", "2A Mechanical Engineering", "Massachusetts Institute of Technology"],
]

rows2 = [
    ["Tioluwalase (Lase) Adelakun", "Psychology", "Harvard University"],
    ["David", "Applied Mathematics", "Harvard University"],
    ["Nyankiir", "Computer Science (Mind, Brain, and Behavior)", "Harvard University"],
    ["Anji", "Neuroscience and Economics", "Harvard University"],
    ["Jason Coreas", "Economics", "Harvard University"],
    ["Yujin Angolio", "Mechanical and Aerospace Engineering", "Princeton University"],
    ["Tomi Johnson", "Woodrow Wilson School", "Princeton University"],
    ["Wunnyuriti Ziblim", "Civil and Environmental Engineering", "Princeton University"],
    ["Aminah Aliu", "Computer Science", "Princeton University"],
    ["Ava Adelaja", "Comparative Literature", "Princeton University"],
    ["Victory Yinka-Banjo", "Computer Science and Molecular Biology", "Massachusetts Institute of Technology"],
    ["Kwesi Afrifa", "Urban Planning and Computer Science", "Massachusetts Institute of Technology"],
    ["Baran Mensah", "Mechanical Engineering", "Massachusetts Institute of Technology"],
    ["Shekina Pita", "Engineering", "Massachusetts Institute of Technology"],
    ["Liliane Kevine Ikirezi", "Electrical Engineering", "University of Pennsylvania"],
    ["Sonari Chidi", "Cinema and Africana Studies", "University of Pennsylvania"],
]

# merge + dedupe while preserving order
seen = OrderedDict()
for row in rows1 + rows2:
    key = tuple(row)
    if key not in seen:
        seen[key] = row

rows = list(seen.values())

outfile = "/Users/yiweili/Documents/EZcommonapp/public_students_combined_deduped.csv"
with open(outfile, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Student Name", "Major", "University"])
    writer.writerows(rows)

print(f"Saved {len(rows)} rows to {outfile}")
# Out:
# Saved 62 rows to /Users/yiweili/Documents/EZcommonapp/public_students_combined_deduped.csv

# %%
import csv

rows = [
    ["Angela Z", "Quantitative Social Science; Comparative Literature", "Dartmouth College"],
    ["Ari G-G", "Government", "Dartmouth College"],
    ["Rachel S", "Government", "Dartmouth College"],
    ["Julia H", "Government", "Dartmouth College"],
    ["Stephanie X", "Cognitive Science; Human-Centered Design", "Dartmouth College"],
    ["Charles B", "Government", "Dartmouth College"],
    ["Will G", "Economics; Environmental Studies", "Dartmouth College"],
    ["Zosia C", "Music; Biological Sciences", "Dartmouth College"],
    ["Lauren H", "Anthropology", "Dartmouth College"],
    ["Julia F", "Quantitative Social Science; Economics", "Dartmouth College"],
    ["Karina R", "Biological Sciences; Human-Centered Design", "Dartmouth College"],
    ["Talia P", "Cognitive Science; Human-Centered Design", "Dartmouth College"],
    ["Sally J", "Biological Sciences", "Dartmouth College"],
    ["Vanessa W", "Pre-Health Track; Biological Sciences", "Dartmouth College"],
    ["Favion H", "Economics; Engineering Sciences", "Dartmouth College"],
    ["Luke A", "Economics; Government", "Dartmouth College"],
    ["Isabelle S", "Environmental Studies; Geography", "Dartmouth College"],
    ["Tanaz M", "Biomedical Engineering Sciences; Classical Studies", "Dartmouth College"],
    ["Annie J", "Government", "Dartmouth College"],
    ["Annabelle N", "Physics; Astronomy", "Dartmouth College"],
    ["LJ J", "Biological Sciences", "Dartmouth College"],
    ["Randle Y", "Engineering Sciences", "Dartmouth College"],
    ["Gracie B", "Religion; Classical Studies", "Dartmouth College"],
    ["Connor FG", "English; Film and Media Studies", "Dartmouth College"],
    ["Brooke N", "Government", "Dartmouth College"],
    ["Hannah B", "Linguistics; Theater", "Dartmouth College"],
    ["Tao C", "Mathematics; Economics", "Dartmouth College"],
    ["Song Ting Tang", "Psychology", "Princeton University"],
    ["Claire Beeli", "English", "Princeton University"],
    ["Brenden Garza", "Anthropology", "Princeton University"],
    ["Drew Sloan", "Anthropology (Prospective, MedAnth track)", "Princeton University"],
    ["Thomas Danz", "Economics", "Princeton University"],
    ["Raquel Rodriguez", "Geosciences", "Princeton University"],
    ["Kevin Yeung", "Chemical and Biological Engineering", "Princeton University"],
    ["Jack Graham", "Economics", "Princeton University"],
    ["Libby Tolman", "Physics", "Princeton University"],
    ["Xander de los Reyes", "Politics", "Princeton University"],
    ["Katie Daniels", "Neuroscience", "Princeton University"],
    ["Richard Ma", "Computer Science", "Princeton University"],
    ["Naomi Hess", "Public Policy", "Princeton University"],
    ["Sophie Williams", "Classics", "Princeton University"],
    ["Zoha Khan", "English", "Princeton University"],
    ["Lake Liao", "Prospective Philosophy", "Princeton University"],
    ["Ive Jones", "Politics", "Princeton University"],
    ["Grace Lee", "Sociology", "Princeton University"],
    ["Roberto Hasbun", "History", "Princeton University"],
    ["Beatrix Bondor", "English", "Princeton University"],
    ["Jenesis Fonseca-Ledezma", "English", "Princeton University"],
    ["Uriel Lin", "Computer Science", "Princeton University"],
    ["Monique Giwa-Osagie", "Community Health", "Tufts University"],
    ["Kiara Rogers", "Biopsychology and Biomedical Sciences", "Tufts University"],
    ["Isaac Ulloa Antonio", "Political Science; Romance Studies", "Tufts University"],
    ["Teagan Mustone", "Philosophy and Civic Studies", "Tufts University"],
    ["Sam Jonas", "Civic Studies; Race, Colonialism, and Diaspora Studies", "Tufts University"],
    ["Evan Kelly", "Computer Science; Environmental Studies", "Tufts University"],
    ["Charlie Husband", "Sociology", "Tufts University"],
    ["Paul Osmond", "English; Spanish; Fine Arts", "Tufts University"],
    ["Sophie Peckler", "Child Studies and Human Development", "Tufts University"],
    ["Alexa Santa Cruz", "Mechanical Engineering", "Tufts University"],
    ["Musashi Kuramoto", "Biochemistry/Biotechnology", "Tufts University"],
    ["Defne Olgun", "International Relations", "Tufts University"],
    ["Rhoda Edwards", "International Relations", "Tufts University"],
    ["Carrie Ortner", "English", "Tufts University"],
    ["Emma Desserault", "English Literature", "Tufts University"],
    ["Jaiden Mosley", "Undeclared / not stated", "Tufts University"],
    ["Joe Peterson", "Undeclared / not stated", "Tufts University"],
    ["Cami M.", "Media Studies and Computer Science", "Massachusetts Institute of Technology"],
    ["Hala K.", "Computer Science and Engineering (6-3, intended)", "Massachusetts Institute of Technology"],
    ["Yan Z.", "Mechanical or Electrical Engineering (planned)", "Massachusetts Institute of Technology"],
    ["Angie F.", "Course 2 / 6 / 2A-6 (exploring)", "Massachusetts Institute of Technology"],
    ["Anna H.", "Physics; Brain and Cognitive Science", "Massachusetts Institute of Technology"],
    ["Kate R.", "Mathematics", "Massachusetts Institute of Technology"],
    ["Shannon M.", "Courses 7 & 18", "Massachusetts Institute of Technology"],
    ["Abigail Diaz", "Hotel Administration / Hospitality (Nolan School)", "Cornell University"],
    ["Jazmin Rodriguez", "Chemical Engineering", "Cornell University"],
    ["Aidan Solomon", "Animal Science", "Cornell University"],
    ["Daniel Di Chiara", "Public Policy", "Cornell University"],
    ["Michaela Eichel", "Information Science", "Cornell University"],
    ["Matthew Norman-Ariztía", "Plant Sciences", "Cornell University"],
    ["Aja'nae Hall-Callaway", "Asian Studies", "Cornell University"],
    ["Lauren Noll", "Urban and Regional Studies", "Cornell University"],
    ["Julian Amundaray", "Human Biology, Health, and Society", "Cornell University"],
    ["Sara Shah", "Architecture", "Cornell University"],
    ["Grace Kelly Fulton", "Civil Engineering", "Cornell University"],
    ["Najiullah Basharat", "Computer Science", "Cornell University"],
    ["Oliver Saul", "Urban and Regional Studies", "Cornell University"],
    ["Jonna Crocker", "Applied Economics and Management", "Cornell University"],
    ["Stella", "Computer Science", "Yale University"],
    ["Abdul", "Sociology", "Yale University"],
    ["Rhayna Poulin", "Psychology (Neuroscience track)", "Yale University"],
    ["Alec", "Chinese; Humanities", "Yale University"],
    ["Keenan Walker", "American Studies", "Yale University"],
    ["Isabella", "Molecular, Cellular, and Developmental Biology; History of Science, Medicine, and Public Health", "Yale University"],
    ["Lily", "American Studies", "Yale University"],
    ["Sadé", "Political Science", "Yale University"],
    ["Casey", "Psychology", "Yale University"],
]

outfile = "/Users/yiweili/Documents/EZcommonapp/public_students_batch2.csv"
with open(outfile, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Student Name", "Major", "University"])
    writer.writerows(rows)

print(f"Saved {len(rows)} rows to {outfile}")
# Out:
# Saved 96 rows to /Users/yiweili/Documents/EZcommonapp/public_students_batch2.csv
